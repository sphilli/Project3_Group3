# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("List of game studios in Europe and the CIS 2020.csv")
df.head(20)
# Out:
#                             Website   Country              Studio  \
# 0                       10tons.com/   Finland              10tons
# 1                 11bitstudios.com/    Poland      11 bit studios
# 2                    1939games.com/   Iceland          1939 Games
# 3                       1button.co/    France             1Button
# 4                      1c.games/ru/    Russia            1C Games
# 5                     1ccgames.com/        UK           1CC Games
# 6                       22cans.com/        UK              22cans
# 7                         2play.se/    Sweden       2Play Studios
# 8                      2zombie.com/    Russia      2 Zombie Games
# 9                  34bigthings.com/     Italy       34 Big Things
# 10            3d2entertainment.com/     Spain    3D2Entertainment
# 11                     3dclouds.it/     Italy            3DClouds
# 12  3division.net/newweb/index.html  Slovenia           3division
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 21 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Website                                                   600 non-null    object
#  1   Country                                                   600 non-null    object
#  2   Studio                                                    600 non-null    object
#  3   Publisher                                                 600 non-null    object
#  4   PC                                                        600 non-null    object
#  5   Mobile                                                    600 non-null    object
#  6   VR                                                        600 non-null    object
#  7   VR only                                                   600 non-null    object
# ...
